# %%
motivation<- c(1,6,9,2,3,4,6,9,1,18,1,3)
working.out<-c(3,6,10,1,3,4,7,8,7,2,3,3)

# %%
length(motivation)
# Out:
# [1] 12

# %%
length(working.out)
# Out:
# [1] 12

# %%
mod1 <- lm(motivation~working.out)

# %%
plot(working.out-motivation)
# Out:
# plot without title

# %%
df<-read.csv("/content/vacation 1234.csv")

# %%
head((df))
# Out:
#   Income Age NumChildren HousePrice MonthlyRestaurant MonthlyEntertainment
# 1 150000 32  3           1505600    300               221
# 2  60000 41  0            627770    127               185
# 3 120000 58  2           1217166    300                54
# 4 180000 59  4           1821064    480               126
# 5 165000 54  3           1674000    452               220
# 6  70000 26  2            712082    162               109
#   Spending Tax   water.spend other.expensive
# 1 12388    15000 75000       630000
# 2  6042     6000 30000       252000
# 3 10395    12000 60000       504000
# 4 14547    18000 90000       756000
# 5 14051    16500 82500       693000
# 6  6540     7000 35000       294000

# %%
head(pairs(df))
# Out:
# NULL
# plot without title

# %%
install.packages("psych")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(psych)

# %%
mod3 <-lm(Spending ~ HousePrice , data=df)

# %%
print(summary(mod3))
# Out:
# Call:
# lm(formula = Spending ~ HousePrice, data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1990.0 -1030.2  -721.7   364.5 11787.9
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 4.549e+03  1.238e+03   3.676 0.000995 ***
# HousePrice  5.548e-03  7.900e-04   7.023 1.23e-07 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2488 on 28 degrees of freedom
# Multiple R-squared:  0.6379,	Adjusted R-squared:  0.6249
# F-statistic: 49.32 on 1 and 28 DF,  p-value: 1.226e-07

# %%
mod4<-lm(Spending~.,data=df)

# %%
print(summary(mod4))
# Out:
# Call:
# lm(formula = Spending ~ ., data = df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1148.5  -847.2   -89.3   392.3  3683.2
#
# Coefficients: (3 not defined because of singularities)
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)           3.287e+03  1.213e+03   2.709   0.0125 *
# Income                4.202e-02  7.355e-03   5.712 8.12e-06 ***
# Age                  -1.908e+01  1.988e+01  -0.960   0.3472
# NumChildren          -2.435e+02  1.734e+02  -1.404   0.1737
# HousePrice            1.207e-03  6.372e-04   1.894   0.0708 .
# MonthlyRestaurant     6.588e+00  2.583e+00   2.550   0.0179 *
# MonthlyEntertainment  2.723e+00  3.098e+00   0.879   0.3885
# Tax                          NA         NA      NA       NA
# water.spend                  NA         NA      NA       NA
# other.expensive              NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...

# %%
mod5<-lm(Income~Spending,data=df)

# %%
pairs.panels(df)
# Out:
# plot without title
