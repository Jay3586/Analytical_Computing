# %% [markdown]
# **Name:** Jay Rakeshbhai Patel <br> Project Name: Olympic Games

# %% [markdown]
# # Objective of the Proposed Research
#
# *   This datasets aims to analyze data about historical Olympic games to modern Olympic games and determine the all the games over the time  .
# *   The main aim in this project to analyze and represents the various factors which have contributed in the Evolution of the Olympic over the time in Graphical Format and perform a comparative study between the various factors.
#
#
# *   To find Factors like Density of Players in Olympic Games on the basis of Age,total number of Male and Femal participants parts in Olympic Game in different years.
# *   To find out the total number of medals won by differents countries by each years.

# %%
x <- read.csv("athlete_events.csv", 
                 row.names = NULL, 
                 stringsAsFactors = FALSE)

# %%
head(x,40)
# Out:
#    ID Name                               Sex Age Height Weight Team
# 1   1 A Dijiang                          M   24  180    80.0   China
# 2   2 A Lamusi                           M   23  170    60.0   China
# 3   3 Gunnar Nielsen Aaby                M   24   NA      NA   Denmark
# 4   4 Edgar Lindenau Aabye               M   34   NA      NA   Denmark/Sweden
# 5   5 Christine Jacoba Aaftink           F   21  185    82.0   Netherlands
# 6   5 Christine Jacoba Aaftink           F   21  185    82.0   Netherlands
# 7   5 Christine Jacoba Aaftink           F   25  185    82.0   Netherlands
# 8   5 Christine Jacoba Aaftink           F   25  185    82.0   Netherlands
# 9   5 Christine Jacoba Aaftink           F   27  185    82.0   Netherlands
# 10  5 Christine Jacoba Aaftink           F   27  185    82.0   Netherlands
# 11  6 Per Knut Aaland                    M   31  188    75.0   United States
# 12  6 Per Knut Aaland                    M   31  188    75.0   United States
# ...

# %% [markdown]
# # Second step
#  Data Exploration

# %% [markdown]
# In this section first take 10 columns using head coad and for numbers of rows and columns for ncol() and nrow().For percentiles of the numerical values usage quantile fuction.

# %%
head(x,10)
# Out:
#    ID Name                     Sex Age Height Weight Team           NOC
# 1  1  A Dijiang                M   24  180    80     China          CHN
# 2  2  A Lamusi                 M   23  170    60     China          CHN
# 3  3  Gunnar Nielsen Aaby      M   24   NA    NA     Denmark        DEN
# 4  4  Edgar Lindenau Aabye     M   34   NA    NA     Denmark/Sweden DEN
# 5  5  Christine Jacoba Aaftink F   21  185    82     Netherlands    NED
# 6  5  Christine Jacoba Aaftink F   21  185    82     Netherlands    NED
# 7  5  Christine Jacoba Aaftink F   25  185    82     Netherlands    NED
# 8  5  Christine Jacoba Aaftink F   25  185    82     Netherlands    NED
# 9  5  Christine Jacoba Aaftink F   27  185    82     Netherlands    NED
# 10 5  Christine Jacoba Aaftink F   27  185    82     Netherlands    NED
#    Games       Year Season City        Sport
# 1  1992 Summer 1992 Summer Barcelona   Basketball
# 2  2012 Summer 2012 Summer London      Judo
# ...

# %% [markdown]
# # 2.2
# Show numbers of rows and colums

# %%
ncol(x)
# Out:
# [1] 15

# %%
nrow(x)
# Out:
# [1] 271116

# %% [markdown]
# # 2.3

# %%
id <- c(x["ID"])
age <- c(x["Age"])
height <- c(x["Height"])
weight <- c(x["Weight"])
year <- c(x["Year"])

# %%
class(id)
# Out:
# [1] "list"

# %%
id <- as.numeric(unlist(id))
age <- as.numeric(unlist(age))
height <- as.numeric(unlist(height))
weight <- as.numeric(unlist(weight))
 year <- as.numeric(unlist(year))

# %%
class(age)
# Out:
# [1] "numeric"

# %%
class(year)
# Out:
# [1] "numeric"

# %%
class(weight)
# Out:
# [1] "numeric"

# %%
quantile(year,probs = seq(0,1,0.25),na.rm =  TRUE)
# Out:
#   0%  25%  50%  75% 100%
# 1896 1960 1988 2002 2016

# %%
quantile(height,probs = seq(0,1,0.25),na.rm =  TRUE)
# Out:
#   0%  25%  50%  75% 100%
#  127  168  175  183  226

# %% [markdown]
# # 2.4

# %%
summary(age)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   10.00   21.00   24.00   25.56   28.00   97.00    9474

# %%
summary(height)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#   127.0   168.0   175.0   175.3   183.0   226.0   60171

# %%
summary(weight)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#    25.0    60.0    70.0    70.7    79.0   214.0   62875

# %%
summary(id)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       1   34643   68205   68249  102097  135571

# %% [markdown]
# # 3

# %% [markdown]
# For this sections i selected age column for the find 10 largest value with the help of head(sort(),decreasing=TRUE fuction.

# %%
head(sort(x[,4], decreasing=TRUE), n=10)
# Out:
#  [1] 97 96 88 88 88 84 81 81 80 80

# %% [markdown]
# # 4
# In this data i elected 5 columns of Name,Age,Team,Noc and Games using head coad and i takes 30 rows data.

# %%
head(x[,c(2,4,7,8,9)],n=30)
# Out:
#    Name                               Age Team           NOC Games
# 1  A Dijiang                          24  China          CHN 1992 Summer
# 2  A Lamusi                           23  China          CHN 2012 Summer
# 3  Gunnar Nielsen Aaby                24  Denmark        DEN 1920 Summer
# 4  Edgar Lindenau Aabye               34  Denmark/Sweden DEN 1900 Summer
# 5  Christine Jacoba Aaftink           21  Netherlands    NED 1988 Winter
# 6  Christine Jacoba Aaftink           21  Netherlands    NED 1988 Winter
# 7  Christine Jacoba Aaftink           25  Netherlands    NED 1992 Winter
# 8  Christine Jacoba Aaftink           25  Netherlands    NED 1992 Winter
# 9  Christine Jacoba Aaftink           27  Netherlands    NED 1994 Winter
# 10 Christine Jacoba Aaftink           27  Netherlands    NED 1994 Winter
# 11 Per Knut Aaland                    31  United States  USA 1992 Winter
# 12 Per Knut Aaland                    31  United States  USA 1992 Winter
# ...

# %% [markdown]
# # 5

# %% [markdown]
# Below graph shows the data about participants age and weights.we can easliy differentiate 60+ or older age participants weight is lower than other participant.secondly,20 to 40 year group participate more in olympic games and them average weight is around 70 to 80.lastly, A very few participants weight is more than 180.

# %%
plot(x[,4], x[,6],xlab = "age", ylab = "weight", main = "source different in weight ",col="Blue")
# Out:
# Plot with title “source different in weight ”

# %%
plot(x[,4], x[,5],xlab = "age", ylab = "height", main = "source different in height ",col="Blue")
# Out:
# Plot with title “source different in height ”

# %%
plot(x[,6], x[,5],xlab = "weight", ylab = "height", main = "source different in height & weight ",col="Blue")
# Out:
# Plot with title “source different in height & weight ”

# %% [markdown]
# # Summary

# %% [markdown]
# Firstly i selected data from kaggle to select data and import file read.csv thenafter share my objective and find data of 40 rows.Second step i found percentile for using quantile fuction.The whole data is about Olympic games and many factors are affect to factor like hight,weight,age, gender, countries and many more. i found the graph about  the factor like Age and weight and also use the sort command to find maximum value of column age.lastly, i find plot about weight and age. In the end i enjoy the my first report.

# %% [markdown]
# #7
# ## Recommendations

# %% [markdown]
# As from the reference of the above study I can recommend to Kellogg's executives regarding the athlete to sponsor, that he has to look at some outcome of the study and can make decision. The outcome contains that the performance of the player is based on the player’s age, height and weight.<br>
# Study shows that age of the athlete can be around 19-27.<br>
# Height can be around 159-179. In cm<br>
# Weight can be around 50-72. In kg <br>
# So., to make a decision to select any athlete Kellogg's executive can check above outcome of the study.
